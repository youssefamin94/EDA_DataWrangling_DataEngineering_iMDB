# %% [markdown]
# #

# %% [markdown]
# # Gathering

# %%
import pandas as pd

# %%
movies = pd.read_csv('MovieAssignmentData.csv')

# %% [markdown]
# # Assessment

# %%
movies
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %% [markdown]
# movies.info()

# %%
movies.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4993.000000  5028.000000              4939.000000
# mean               140.194272   107.201074               686.509212
# std                121.601675    25.197441              2813.328607
# min                  1.000000     7.000000                 0.000000
# 25%                 50.000000    93.000000                 7.000000
# 50%                110.000000   103.000000                49.000000
# 75%                195.000000   118.000000               194.500000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             5020.000000             5036.000000  4.159000e+03
# mean               645.009761             6560.047061  4.846841e+07
# std               1665.041728            15020.759120  6.845299e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %%
list(movies)
# Out:
# ['color',
#  'director_name',
#  'num_critic_for_reviews',
#  'duration',
#  'director_facebook_likes',
#  'actor_3_facebook_likes',
#  'actor_2_name',
#  'actor_1_facebook_likes',
#  'gross',
#  'genres',
#  'actor_1_name',
#  'movie_title',
#  'num_voted_users',
#  'cast_total_facebook_likes',
#  'actor_3_name',
#  'facenumber_in_poster',
#  'plot_keywords',
#  'movie_imdb_link',
#  'num_user_for_reviews',
#  'language',
#  'country',
#  'content_rating',
#  'budget',
#  'title_year',
#  'actor_2_facebook_likes',
#  'imdb_score',
#  'aspect_ratio',
#  'movie_facebook_likes']

# %%
movies.country
# Out:
# 0          USA
# 1          USA
# 2           UK
# 3          USA
# 4          NaN
#          ...
# 5038    Canada
# 5039       USA
# 5040       USA
# 5041       USA
# 5042       USA
# Name: country, Length: 5043, dtype: object

# %%
movies['country'].unique()
# Out:
# array(['USA', 'UK', nan, 'New Zealand', 'Canada', 'Australia', 'Belgium',
#        'Japan', 'Germany', 'China', 'France', 'New Line', 'Mexico',
#        'Spain', 'Hong Kong', 'Czech Republic', 'India', 'Soviet Union',
#        'South Korea', 'Peru', 'Italy', 'Russia', 'Aruba', 'Denmark',
#        'Libya', 'Ireland', 'South Africa', 'Iceland', 'Switzerland',
#        'Romania', 'West Germany', 'Chile', 'Netherlands', 'Hungary',
#        'Panama', 'Greece', 'Sweden', 'Norway', 'Taiwan', 'Official site',
#        'Cambodia', 'Thailand', 'Slovakia', 'Bulgaria', 'Iran', 'Poland',
#        'Georgia', 'Turkey', 'Nigeria', 'Brazil', 'Finland', 'Bahamas',
#        'Argentina', 'Colombia', 'Israel', 'Egypt', 'Kyrgyzstan',
#        'Indonesia', 'Pakistan', 'Slovenia', 'Afghanistan',
#        'Dominican Republic', 'Cameroon', 'United Arab Emirates', 'Kenya',
#        'Philippines'], dtype=object)

# %%
movies[movies.country == 'Official site']
# Out:
#       color director_name  num_critic_for_reviews  duration  \
# 2675  Color   Shana Feste                   135.0     117.0
#
#       director_facebook_likes  actor_3_facebook_likes  actor_2_name  \
# 2675                     19.0                   461.0  Cinda McCain
#
#       actor_1_facebook_likes       gross       genres  ...  \
# 2675                  3000.0  20218921.0  Drama|Music  ...
#
#      num_user_for_reviews language        country  content_rating      budget  \
# 2675                114.0  English  Official site           PG-13  15000000.0
#
#       title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 2675      2010.0                  646.0        6.3          2.35
#
#      movie_facebook_likes
# 2675                    0
#
# [1 rows x 28 columns]

# %%
movies[movies.country == 'New Line']
# Out:
#      color  director_name  num_critic_for_reviews  duration  \
# 281  Color  Peter Chelsom                    62.0     104.0
#
#      director_facebook_likes  actor_3_facebook_likes   actor_2_name  \
# 281                     23.0                   591.0  Warren Beatty
#
#      actor_1_facebook_likes      gross          genres  ...  \
# 281                   752.0  6712451.0  Comedy|Romance  ...
#
#     num_user_for_reviews language   country  content_rating      budget  \
# 281                 89.0  English  New Line               R  90000000.0
#
#      title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 281      2001.0                  631.0        4.4          1.85
#
#     movie_facebook_likes
# 281                   53
#
# [1 rows x 28 columns]

# %%
sum(movies.country.isnull())
# Out:
# 5

# %%
sum(movies.language.isnull())
# Out:
# 12

# %%
movies.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
movies.tail()
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 5038  Color       Scott Smith                     1.0      87.0
# 5039  Color               NaN                    43.0      43.0
# 5040  Color  Benjamin Roberds                    13.0      76.0
# 5041  Color       Daniel Hsia                    14.0     100.0
# 5042  Color          Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 5038                      2.0                   318.0     Daphne Zuniga
# 5039                      NaN                   319.0     Valorie Curry
# 5040                      0.0                     0.0     Maxwell Moody
# 5041                      0.0                   489.0     Daniel Henney
# 5042                     16.0                    16.0  Brian Herzlinger
#
#       actor_1_facebook_likes    gross                        genres  ...  \
# ...

# %%
movies.country.isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 5038    False
# 5039    False
# 5040    False
# 5041    False
# 5042    False
# Name: country, Length: 5043, dtype: bool

# %%
movies.isnull().sum(axis=0)
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
movies.isnull().sum(axis=1)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4       14
#         ..
# 5038     4
# 5039     5
# 5040     4
# 5041     2
# 5042     0
# Length: 5043, dtype: int64

# %%
movies.genres
# Out:
# 0       Action|Adventure|Fantasy|Sci-Fi
# 1              Action|Adventure|Fantasy
# 2             Action|Adventure|Thriller
# 3                       Action|Thriller
# 4                           Documentary
#                      ...
# 5038                       Comedy|Drama
# 5039       Crime|Drama|Mystery|Thriller
# 5040              Drama|Horror|Thriller
# 5041               Comedy|Drama|Romance
# 5042                        Documentary
# Name: genres, Length: 5043, dtype: object

# %% [markdown]
# # Cleaning

# %% [markdown]
# ### 1) Quality

# %% [markdown]
# #### Starting the clean dataset with no rows with more than 10 missing values

# %%
movies_clean = movies.copy()
movies_clean = movies_clean[movies_clean.isnull().sum(axis=1) < 10]

# %%
movies_clean
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 5     Color     Andrew Stanton                   462.0     132.0
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %% [markdown]
# #### Filling some columns null values with every its average value

# %%
avg_1 = movies_clean.num_critic_for_reviews.sum()/len(movies.columns)
avg_3 = movies_clean.num_user_for_reviews.sum()/len(movies.columns)
avg_4 = movies_clean.aspect_ratio.sum()/len(movies.columns)

# %%
movies_clean['num_critic_for_reviews'] = movies_clean.num_critic_for_reviews.fillna(avg_1)
movies_clean['num_user_for_reviews'] = movies_clean.num_user_for_reviews.fillna(avg_3)
movies_clean['aspect_ratio'] = movies_clean.aspect_ratio.fillna(avg_4)

# %%
movies_clean.isnull().sum()
# Out:
# color                         17
# director_name                101
# num_critic_for_reviews         0
# duration                      14
# director_facebook_likes      101
# actor_3_facebook_likes        18
# actor_2_name                   9
# actor_1_facebook_likes         6
# gross                        878
# genres                         0
# actor_1_name                   6
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  18
# facenumber_in_poster          13
# plot_keywords                150
# movie_imdb_link                0
# num_user_for_reviews           0
# language                      10
# country                        3
# content_rating               297
# budget                       488
# title_year                   103
# actor_2_facebook_likes         9
# imdb_score                     0
# aspect_ratio                   0
# movie_facebook_likes           0
# dtype: int64

# %% [markdown]
# #### Removing records that have null values in certain coulmns (for classification)

# %%
movies_clean = movies_clean[~movies_clean.duration.isnull()]
movies_clean = movies_clean[~movies_clean.gross.isnull()]
movies_clean = movies_clean[~movies_clean.budget.isnull()]
movies_clean = movies_clean[~movies_clean.director_facebook_likes.isnull()]
movies_clean = movies_clean[~movies_clean.actor_3_facebook_likes.isnull()]
movies_clean = movies_clean[~movies_clean.actor_2_facebook_likes.isnull()]
movies_clean = movies_clean[~movies_clean.actor_1_facebook_likes.isnull()]
movies_clean = movies_clean[~movies_clean.cast_total_facebook_likes.isnull()]
movies_clean = movies_clean[~movies_clean.movie_facebook_likes.isnull()]

# %%
movies_clean.content_rating.hist()

# %%
movies_clean.color.hist()

# %%
movies_clean.language.hist()

# %%
movies_clean['content_rating'] = movies_clean.content_rating.fillna('PG-13')
movies_clean['color'] = movies_clean.color.fillna('color')
movies_clean['language'] = movies_clean.language.fillna('English')

# %%
movies_clean.isnull().sum()
# Out:
# color                         0
# director_name                 0
# num_critic_for_reviews        0
# duration                      0
# director_facebook_likes       0
# actor_3_facebook_likes        0
# actor_2_name                  0
# actor_1_facebook_likes        0
# gross                         0
# genres                        0
# actor_1_name                  0
# movie_title                   0
# num_voted_users               0
# cast_total_facebook_likes     0
# actor_3_name                  0
# facenumber_in_poster          6
# plot_keywords                29
# movie_imdb_link               0
# num_user_for_reviews          0
# language                      0
# country                       0
# content_rating                0
# budget                        0
# title_year                    0
# actor_2_facebook_likes        0
# imdb_score                    0
# aspect_ratio                  0
# movie_facebook_likes          0
# dtype: int64

# %%
movies_clean
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 5     Color     Andrew Stanton                   462.0     132.0
# ...     ...                ...                     ...       ...
# 5033  Color      Shane Carruth                   143.0      77.0
# 5034  Color   Neill Dela Llana                    35.0      80.0
# 5035  Color   Robert Rodriguez                    56.0      81.0
# 5037  Color       Edward Burns                    14.0      95.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# 0                         0.0                   855.0    Joel David Moore
# ...

# %%
movies_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3880 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      3880 non-null   object
#  1   director_name              3880 non-null   object
#  2   num_critic_for_reviews     3880 non-null   float64
#  3   duration                   3880 non-null   float64
#  4   director_facebook_likes    3880 non-null   float64
#  5   actor_3_facebook_likes     3880 non-null   float64
#  6   actor_2_name               3880 non-null   object
#  7   actor_1_facebook_likes     3880 non-null   float64
#  8   gross                      3880 non-null   float64
#  9   genres                     3880 non-null   object
#  10  actor_1_name               3880 non-null   object
#  11  movie_title                3880 non-null   object
#  12  num_voted_users            3880 non-null   int64
# ...

# %%
movies_clean.isnull().sum()
# Out:
# color                         0
# director_name                 0
# num_critic_for_reviews        0
# duration                      0
# director_facebook_likes       0
# actor_3_facebook_likes        0
# actor_2_name                  0
# actor_1_facebook_likes        0
# gross                         0
# genres                        0
# actor_1_name                  0
# movie_title                   0
# num_voted_users               0
# cast_total_facebook_likes     0
# actor_3_name                  0
# facenumber_in_poster          6
# plot_keywords                29
# movie_imdb_link               0
# num_user_for_reviews          0
# language                      0
# country                       0
# content_rating                0
# budget                        0
# title_year                    0
# actor_2_facebook_likes        0
# imdb_score                    0
# aspect_ratio                  0
# movie_facebook_likes          0
# dtype: int64

# %% [markdown]
# ## Filling non-numeric columns' null values with the most frequent value:
# - plot_keywords               29 (will be filled later in the tidiness stage)

# %%
movies_clean.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             3880.000000  3880.000000              3880.000000
# mean               169.909601   109.952835               783.240979
# std                417.550805    22.682495              3021.708213
# min                  1.000000    34.000000                 0.000000
# 25%                 73.000000    95.000000                10.000000
# 50%                134.500000   106.000000                58.000000
# 75%                222.000000   120.000000               226.000000
# max              24999.250000   330.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             3880.000000             3880.000000  3.880000e+03
# mean               753.717526             7596.616495  5.117361e+07
# std               1866.838312            15378.452439  6.985634e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %% [markdown]
# #### Changing these columns' data type from float to integer

# %%
movies_clean.director_facebook_likes = movies_clean.director_facebook_likes.astype(int)
movies_clean.actor_1_facebook_likes = movies_clean.actor_1_facebook_likes.astype(int)
movies_clean.actor_2_facebook_likes = movies_clean.actor_2_facebook_likes.astype(int)
movies_clean.actor_3_facebook_likes = movies_clean.actor_3_facebook_likes.astype(int)
movies_clean.actor_3_facebook_likes = movies_clean.movie_facebook_likes.astype(int)
movies_clean.gross = movies_clean.gross.astype(int)
movies_clean.budget = movies_clean.budget.astype(int)
movies_clean.num_critic_for_reviews	 = movies_clean.num_critic_for_reviews	.astype(int)
movies_clean.duration = movies_clean.duration.astype(int)
movies_clean.num_user_for_reviews = movies_clean.num_user_for_reviews.astype(int)
movies_clean.title_year = movies_clean.title_year.astype(int)

# %%
movies_clean.content_rating.describe()
# Out:
# count     3880
# unique      12
# top          R
# freq      1736
# Name: content_rating, dtype: object

# %%
movies_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3880 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      3880 non-null   object
#  1   director_name              3880 non-null   object
#  2   num_critic_for_reviews     3880 non-null   int64
#  3   duration                   3880 non-null   int64
#  4   director_facebook_likes    3880 non-null   int64
#  5   actor_3_facebook_likes     3880 non-null   int64
#  6   actor_2_name               3880 non-null   object
#  7   actor_1_facebook_likes     3880 non-null   int64
#  8   gross                      3880 non-null   int64
#  9   genres                     3880 non-null   object
#  10  actor_1_name               3880 non-null   object
#  11  movie_title                3880 non-null   object
#  12  num_voted_users            3880 non-null   int64
# ...

# %%
movies_clean.isnull().sum()
# Out:
# color                         0
# director_name                 0
# num_critic_for_reviews        0
# duration                      0
# director_facebook_likes       0
# actor_3_facebook_likes        0
# actor_2_name                  0
# actor_1_facebook_likes        0
# gross                         0
# genres                        0
# actor_1_name                  0
# movie_title                   0
# num_voted_users               0
# cast_total_facebook_likes     0
# actor_3_name                  0
# facenumber_in_poster          6
# plot_keywords                29
# movie_imdb_link               0
# num_user_for_reviews          0
# language                      0
# country                       0
# content_rating                0
# budget                        0
# title_year                    0
# actor_2_facebook_likes        0
# imdb_score                    0
# aspect_ratio                  0
# movie_facebook_likes          0
# dtype: int64

# %% [markdown]
# #### Replacing invalid country names with the most frequent one (USA)

# %%
movies_clean['country'] = movies_clean.country.replace('Official site','USA')
movies_clean['country'] = movies_clean.country.replace('New Line','USA')

# %%
movies_clean['country'].unique()
# Out:
# array(['USA', 'UK', 'New Zealand', 'Canada', 'Australia', 'Germany',
#        'China', 'France', 'Japan', 'Spain', 'Hong Kong', 'Czech Republic',
#        'Peru', 'South Korea', 'India', 'Aruba', 'Denmark', 'Belgium',
#        'Ireland', 'South Africa', 'Italy', 'Romania', 'Chile',
#        'Netherlands', 'Hungary', 'Russia', 'Mexico', 'Greece', 'Taiwan',
#        'Thailand', 'Iran', 'West Germany', 'Georgia', 'Iceland', 'Brazil',
#        'Finland', 'Norway', 'Argentina', 'Colombia', 'Poland', 'Israel',
#        'Indonesia', 'Afghanistan', 'Sweden', 'Philippines'], dtype=object)

# %% [markdown]
# #### Full country names sometimes, abbreviations other times

# %%
movies_clean['country'] = movies_clean.country.replace('USA','United State of America')
movies_clean['country'] = movies_clean.country.replace('UK','United Kingdom')

# %%
movies_clean['country'].unique()
# Out:
# array(['United State of America', 'United Kingdom', 'New Zealand',
#        'Canada', 'Australia', 'Germany', 'China', 'France', 'Japan',
#        'Spain', 'Hong Kong', 'Czech Republic', 'Peru', 'South Korea',
#        'India', 'Aruba', 'Denmark', 'Belgium', 'Ireland', 'South Africa',
#        'Italy', 'Romania', 'Chile', 'Netherlands', 'Hungary', 'Russia',
#        'Mexico', 'Greece', 'Taiwan', 'Thailand', 'Iran', 'West Germany',
#        'Georgia', 'Iceland', 'Brazil', 'Finland', 'Norway', 'Argentina',
#        'Colombia', 'Poland', 'Israel', 'Indonesia', 'Afghanistan',
#        'Sweden', 'Philippines'], dtype=object)

# %% [markdown]
# ### 2) Tidiness

# %% [markdown]
# #### Splitting multi-valued columns into 2 columns

# %%
movies_clean['plot_keyword_1'] = movies_clean['plot_keywords'].str.split('|').str.get(0)
movies_clean['plot_keyword_2'] = movies_clean['plot_keywords'].str.split('|').str.get(1)

# %%
movies_clean = movies_clean.drop(['plot_keywords'], axis=1)

# %%
movies_clean['genre_1'] = movies_clean['genres'].str.split('|').str.get(0)
movies_clean['genre_2'] = movies_clean['genres'].str.split('|').str.get(1)
movies_clean['genre_2'] = movies_clean.genre_2.fillna(movies_clean['genre_1'])

# %%
movies_clean = movies_clean.drop(['genres'],axis=1)

# %%
movies_clean.isnull().sum()
# Out:
# color                         0
# director_name                 0
# num_critic_for_reviews        0
# duration                      0
# director_facebook_likes       0
# actor_3_facebook_likes        0
# actor_2_name                  0
# actor_1_facebook_likes        0
# gross                         0
# actor_1_name                  0
# movie_title                   0
# num_voted_users               0
# cast_total_facebook_likes     0
# actor_3_name                  0
# facenumber_in_poster          6
# movie_imdb_link               0
# num_user_for_reviews          0
# language                      0
# country                       0
# content_rating                0
# budget                        0
# title_year                    0
# actor_2_facebook_likes        0
# imdb_score                    0
# aspect_ratio                  0
# movie_facebook_likes          0
# plot_keyword_1               29
# plot_keyword_2               41
# genre_1                       0
# ...

# %%
x = movies_clean['plot_keyword_1'].value_counts().idxmax()
y = movies_clean['plot_keyword_2'].value_counts().idxmax()

# %%
movies_clean['plot_keyword_1'] = movies_clean.plot_keyword_1.fillna(x)
movies_clean['plot_keyword_2'] = movies_clean.plot_keyword_2.fillna(y)

# %%
movies_clean.isnull().sum()
# Out:
# color                        0
# director_name                0
# num_critic_for_reviews       0
# duration                     0
# director_facebook_likes      0
# actor_3_facebook_likes       0
# actor_2_name                 0
# actor_1_facebook_likes       0
# gross                        0
# actor_1_name                 0
# movie_title                  0
# num_voted_users              0
# cast_total_facebook_likes    0
# actor_3_name                 0
# facenumber_in_poster         6
# movie_imdb_link              0
# num_user_for_reviews         0
# language                     0
# country                      0
# content_rating               0
# budget                       0
# title_year                   0
# actor_2_facebook_likes       0
# imdb_score                   0
# aspect_ratio                 0
# movie_facebook_likes         0
# plot_keyword_1               0
# plot_keyword_2               0
# genre_1                      0
# genre_2                      0
# ...

# %%
movies_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3880 entries, 0 to 5042
# Data columns (total 30 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      3880 non-null   object
#  1   director_name              3880 non-null   object
#  2   num_critic_for_reviews     3880 non-null   int64
#  3   duration                   3880 non-null   int64
#  4   director_facebook_likes    3880 non-null   int64
#  5   actor_3_facebook_likes     3880 non-null   int64
#  6   actor_2_name               3880 non-null   object
#  7   actor_1_facebook_likes     3880 non-null   int64
#  8   gross                      3880 non-null   int64
#  9   actor_1_name               3880 non-null   object
#  10  movie_title                3880 non-null   object
#  11  num_voted_users            3880 non-null   int64
#  12  cast_total_facebook_likes  3880 non-null   int64
# ...

# %% [markdown]
# #### Classification

# %%
import numpy as np
conditions = [
    (movies_clean['imdb_score'] >= 7.8),
    ((movies_clean['imdb_score'] < 7.8) & (movies_clean['imdb_score'] >= 5.5)),
    (movies_clean['imdb_score'] < 5.5)]

# create a list of the values we want to assign for each condition
values = ['Class_1', 'Class_2','Class_3']

# create a new column and use np.select to assign values to it using our lists as arguments
movies_clean['IMDB_Category'] = np.select(conditions, values)

# display updated DataFrame
movies_clean.head(10)
# Out:
#     color      director_name  num_critic_for_reviews  duration  \
# 0   Color      James Cameron                     723       178
# 1   Color     Gore Verbinski                     302       169
# 2   Color         Sam Mendes                     602       148
# 3   Color  Christopher Nolan                     813       164
# 5   Color     Andrew Stanton                     462       132
# 6   Color          Sam Raimi                     392       156
# 7   Color       Nathan Greno                     324       100
# 8   Color        Joss Whedon                     635       141
# 9   Color        David Yates                     375       153
# 10  Color        Zack Snyder                     673       183
#
#     director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                         0                   33000   Joel David Moore
# 1                       563                       0      Orlando Bloom
# ...

# %%
movies_clean[movies_clean.IMDB_Category == "Class_2"]
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 1     Color    Gore Verbinski                     302       169
# 2     Color        Sam Mendes                     602       148
# 5     Color    Andrew Stanton                     462       132
# 6     Color         Sam Raimi                     392       156
# 8     Color       Joss Whedon                     635       141
# ...     ...               ...                     ...       ...
# 5033  Color     Shane Carruth                     143        77
# 5034  Color  Neill Dela Llana                      35        80
# 5035  Color  Robert Rodriguez                      56        81
# 5037  Color      Edward Burns                      14        95
# 5042  Color          Jon Gunn                      43        90
#
#       director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# 1                         563                       0       Orlando Bloom
# ...

# %%
movies_clean[movies_clean.IMDB_Category == "Class_1"].imdb_score.describe()
# Out:
# count    356.000000
# mean       8.092135
# std        0.290109
# min        7.800000
# 25%        7.900000
# 50%        8.000000
# 75%        8.225000
# max        9.300000
# Name: imdb_score, dtype: float64

# %%
movies_clean[movies_clean.IMDB_Category == "Class_2"].imdb_score.describe()
# Out:
# count    2933.000000
# mean        6.624037
# std         0.601424
# min         5.500000
# 25%         6.100000
# 50%         6.600000
# 75%         7.100000
# max         7.700000
# Name: imdb_score, dtype: float64

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

X = movies_clean[['gross','budget','title_year','director_facebook_likes','actor_1_facebook_likes','actor_2_facebook_likes','actor_3_facebook_likes','cast_total_facebook_likes','duration']]
Y = movies_clean.IMDB_Category

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=1) # 70% training and 30% test

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7164948453608248

# %%
tree.plot_tree(clf);

# %%
# %matplotlib inline

# %%
movies_clean.title_year.hist()

# %%
movies_clean.imdb_score.hist()

# %%
movies_clean.content_rating.hist()

# %% [markdown]
# x1 = movies_clean

# %%
movies_clean.imdb_score.plot(kind='box')

# %%
movies_clean.duration.plot(kind='box')

# %%
#+correlated
movies_clean.plot(y='budget', x='title_year', kind='scatter',xlim = (1950,2018),ylim = (0,300000000))

# %%
#uncorrelated 
movies_clean.plot(y='gross', x='budget', kind='scatter',xlim = (0,150000000),ylim = (0,80000000))
